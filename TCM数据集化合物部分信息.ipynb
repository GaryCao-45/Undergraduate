# %%
import os
import pandas as pd
name=pd.read_excel('F:\\Paper\\Code\\物质结构式及其信息来源.xlsx', usecols='A:G')

# %%
os.getcwd()
# Out:
# 'F:\\Paper\\Code'

# %%
name
# Out:
#       ID         分子式  Unnamed: 2  \
# 0      1   C27H34O11         NaN
# 1      2    C16H18O9         NaN
# 2      3    C10H15NO         NaN
# 3      4  C16H10N2O2         NaN
# 4      5    C12H22O2         NaN
# ..   ...         ...         ...
# 483  484    C29H30O8         NaN
# 484  485   C51H46O14         NaN
# 485  486   C51H46O14         NaN
# 486  487   C51H46O14         NaN
# 487  488   C51H46O14         NaN
#
#                                                     名称  Unnamed: 4  \
# 0                                                  连翘苷         NaN
# 1                                                  绿原酸         NaN
# 2                                                  麻黄碱         NaN
# 3                                                  靛玉红         NaN
# 4                                                 癸酰乙醛         NaN
# ..                                                 ...         ...
# 483  (5R,6S,12S,13R)-5,13-dihydroxy-8-methoxy-3-(4-...         NaN
# ...

# %%
name=name.dropna(axis=1, how='all')

# %%
name.to_excel(os.getcwd() + '\\name.xlsx')
